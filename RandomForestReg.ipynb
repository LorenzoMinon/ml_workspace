# %%
import pandas as pd

# %%
import seaborn as sns

# %%
sns.get_dataset_names()
# Out:
# ['anagrams',
#  'anscombe',
#  'attention',
#  'brain_networks',
#  'car_crashes',
#  'diamonds',
#  'dots',
#  'dowjones',
#  'exercise',
#  'flights',
#  'fmri',
#  'geyser',
#  'glue',
#  'healthexp',
#  'iris',
#  'mpg',
#  'penguins',
#  'planets',
#  'seaice',
#  'taxis',
#  'tips',
#  'titanic']

# %%
healthexp = sns.load_dataset('healthexp')

# %%
healthexp.tail(10)
# Out:
#      Year        Country  Spending_USD  Life_Expectancy
# 264  2019         France      5167.839             82.9
# 265  2019  Great Britain      4385.463             81.4
# 266  2019          Japan      4610.794             84.4
# 267  2019            USA     10855.517             78.8
# 268  2020         Canada      5828.324             81.7
# 269  2020        Germany      6938.983             81.1
# 270  2020         France      5468.418             82.3
# 271  2020  Great Britain      5018.700             80.4
# 272  2020          Japan      4665.641             84.7
# 273  2020            USA     11859.179             77.0

# %%
healthexp = pd.get_dummies(healthexp)

# %%
healthexp.head()
# Out:
#    Year  Spending_USD  Life_Expectancy  Country_Canada  Country_France  \
# 0  1970       252.311             70.6           False           False
# 1  1970       192.143             72.2           False            True
# 2  1970       123.993             71.9           False           False
# 3  1970       150.437             72.0           False           False
# 4  1970       326.961             70.9           False           False
#
#    Country_Germany  Country_Great Britain  Country_Japan  Country_USA
# 0             True                  False          False        False
# 1            False                  False          False        False
# 2            False                   True          False        False
# 3            False                  False           True        False
# 4            False                  False          False         True

# %%
X = healthexp.drop(['Life_Expectancy'], axis=1)

# %%
y = healthexp['Life_Expectancy']

# %%
y
# Out:
# 0      70.6
# 1      72.2
# 2      71.9
# 3      72.0
# 4      70.9
#        ...
# 269    81.1
# 270    82.3
# 271    80.4
# 272    84.7
# 273    77.0
# Name: Life_Expectancy, Length: 274, dtype: float64

# %%
X
# Out:
#      Year  Spending_USD  Country_Canada  Country_France  Country_Germany  \
# 0    1970       252.311           False           False             True
# 1    1970       192.143           False            True            False
# 2    1970       123.993           False           False            False
# 3    1970       150.437           False           False            False
# 4    1970       326.961           False           False            False
# ..    ...           ...             ...             ...              ...
# 269  2020      6938.983           False           False             True
# 270  2020      5468.418           False            True            False
# 271  2020      5018.700           False           False            False
# 272  2020      4665.641           False           False            False
# 273  2020     11859.179           False           False            False
#
#      Country_Great Britain  Country_Japan  Country_USA
# 0                    False          False        False
# 1                    False          False        False
# 2                     True          False        False
# 3                    False           True        False
# 4                    False          False         True
# ..                     ...            ...          ...
# 269                  False          False        False
# 270                  False          False        False
# 271                   True          False        False
# 272                  False           True        False
# 273                  False          False         True
#
# [274 rows x 8 columns]

# %%
from sklearn.model_selection import train_test_split

# %%
X_train,X_test,y_train,y_test = train_test_split(X,y,test_size=0.2,random_state=19)

# %%
from sklearn.ensemble import RandomForestRegressor

# %%
rfr = RandomForestRegressor(random_state=13)

# %%
rfr.fit(X_train,y_train)
# Out:
# RandomForestRegressor(random_state=13)

# %%
y_pred = rfr.predict(X_test)

# %%
from sklearn.metrics import mean_absolute_error,mean_squared_error,r2_score

# %%
mean_absolute_error(y_test,y_pred)
# Out:
# 0.25916363636361917

# %%
mean_squared_error(y_test,y_pred)
# Out:
# 0.10221141818181628

# %%
r2_score(y_test,y_pred)
# Out:
# 0.9910457602615238

# %%
param_grid = {
    'n_estimators':[100,200,300],
    'max_depth':[10,20,30],
    'min_samples_split': [2,5,10],
    'min_samples_leaf': [1,2,4]
}

# %%
from sklearn.model_selection import GridSearchCV

# %%
rfr_cv = GridSearchCV(rfr,param_grid=param_grid,cv=3,n_jobs=-1)

# %%
rfr_cv.fit(X_train,y_train)
# Out:
# GridSearchCV(cv=3, estimator=RandomForestRegressor(random_state=13), n_jobs=-1,
#              param_grid={'max_depth': [10, 20, 30],
#                          'min_samples_leaf': [1, 2, 4],
#                          'min_samples_split': [2, 5, 10],
#                          'n_estimators': [100, 200, 300]})

# %%
y_pred2= rfr_cv.predict(X_test)

# %%
mean_absolute_error(y_test,y_pred2)
# Out:
# 0.25089696969702713

# %%
mean_squared_error(y_test,y_pred2)
# Out:
# 0.09636595151516295

# %%
r2_score(y_test,y_pred2)
# Out:
# 0.9915578528520343

# %%
import optuna

# %%
from sklearn.model_selection import cross_val_score

# %%
def objective(trial):
    n_estimators = trial.suggest_int('n_estimators', 100,1000)
    max_depth = trial.suggest_int('max_depth', 10,50)
    min_samples_split = trial.suggest_int('min_samples_split', 2,32)
    min_samples_leaf = trial.suggest_int('min_samples_leaf', 2,32)

    model = RandomForestRegressor(n_estimators = n_estimators,
                                 max_depth= max_depth, 
                                 min_samples_split=min_samples_split,
                                 min_samples_leaf=min_samples_leaf)
    score = cross_val_score(model, X_train, y_train, cv=5,scoring = 'neg_mean_squared_error', n_jobs=-1)

    return score

# %%
study = optuna.create_study(direction='maximize', sampler=optuna.samplers.RandomSampler(seed=42))
# Out:
# [I 2024-09-25 12:03:34,487] A new study created in memory with name: no-name-fa6f943d-36e0-43df-bd10-c785d1ff47b6

# %%
study.optimize(objective, n_trials=200)
# Out:
# [W 2024-09-25 12:08:53,291] Trial 200 failed with parameters: {'n_estimators': 737, 'max_depth': 16, 'min_samples_split': 19, 'min_samples_leaf': 20} because of the following error: The value array([-2.09383457, -2.79786655, -2.43848225, -2.52289033, -2.91989351]) could not be cast to float.
# [W 2024-09-25 12:08:53,292] Trial 200 failed with value array([-2.09383457, -2.79786655, -2.43848225, -2.52289033, -2.91989351]).
# [W 2024-09-25 12:08:53,901] Trial 201 failed with parameters: {'n_estimators': 482, 'max_depth': 40, 'min_samples_split': 30, 'min_samples_leaf': 30} because of the following error: The value array([-2.50475483, -3.83448961, -2.83263585, -4.19680555, -3.9143121 ]) could not be cast to float.
# [W 2024-09-25 12:08:53,902] Trial 201 failed with value array([-2.50475483, -3.83448961, -2.83263585, -4.19680555, -3.9143121 ]).
# [W 2024-09-25 12:08:54,530] Trial 202 failed with parameters: {'n_estimators': 506, 'max_depth': 14, 'min_samples_split': 32, 'min_samples_leaf': 28} because of the following error: The value array([-2.52300731, -3.52052206, -2.74967756, -3.60111446, -3.53418859]) could not be cast to float.
# [W 2024-09-25 12:08:54,532] Trial 202 failed with value array([-2.52300731, -3.52052206, -2.74967756, -3.60111446, -3.53418859]).
# [W 2024-09-25 12:08:54,785] Trial 203 failed with parameters: {'n_estimators': 212, 'max_depth': 47, 'min_samples_split': 28, 'min_samples_leaf': 18} because of the following error: The value array([-2.0726091 , -2.63110746, -2.30024274, -2.43743035, -2.90482088]) could not be cast to float.
# [W 2024-09-25 12:08:54,786] Trial 203 failed with value array([-2.0726091 , -2.63110746, -2.30024274, -2.43743035, -2.90482088]).
# [W 2024-09-25 12:08:56,658] Trial 204 failed with parameters: {'n_estimators': 632, 'max_depth': 26, 'min_samples_split': 3, 'min_samples_leaf': 12} because of the following error: The value array([-1.77069646, -1.91341259, -1.74805445, -1.87731787, -2.45807419]) could not be cast to float.
# [W 2024-09-25 12:08:56,659] Trial 204 failed with value array([-1.77069646, -1.91341259, -1.74805445, -1.87731787, -2.45807419]).
# [W 2024-09-25 12:08:57,575] Trial 205 failed with parameters: {'n_estimators': 823, 'max_depth': 10, 'min_samples_split': 12, 'min_samples_leaf': 14} because of the following error: The value array([-1.92361148, -2.21614324, -1.98134474, -2.07032029, -2.67620333]) could not be cast to float.
# [W 2024-09-25 12:08:57,575] Trial 205 failed with value array([-1.92361148, -2.21614324, -1.98134474, -2.07032029, -2.67620333]).
# [W 2024-09-25 12:08:58,283] Trial 206 failed with parameters: {'n_estimators': 584, 'max_depth': 47, 'min_samples_split': 12, 'min_samples_leaf': 12} because of the following error: The value array([-1.70740087, -1.91849348, -1.74677848, -1.8678056 , -2.51545154]) could not be cast to float.
# [W 2024-09-25 12:08:58,284] Trial 206 failed with value array([-1.70740087, -1.91849348, -1.74677848, -1.8678056 , -2.51545154]).
# [W 2024-09-25 12:08:59,108] Trial 207 failed with parameters: {'n_estimators': 764, 'max_depth': 28, 'min_samples_split': 8, 'min_samples_leaf': 16} because of the following error: The value array([-2.07229622, -2.44437339, -2.1156919 , -2.28594383, -2.78717398]) could not be cast to float.
# [W 2024-09-25 12:08:59,109] Trial 207 failed with value array([-2.07229622, -2.44437339, -2.1156919 , -2.28594383, -2.78717398]).
# [W 2024-09-25 12:08:59,395] Trial 208 failed with parameters: {'n_estimators': 226, 'max_depth': 17, 'min_samples_split': 17, 'min_samples_leaf': 14} because of the following error: The value array([-1.90038413, -2.22080784, -1.98100812, -2.08576998, -2.68346188]) could not be cast to float.
# [W 2024-09-25 12:08:59,396] Trial 208 failed with value array([-1.90038413, -2.22080784, -1.98100812, -2.08576998, -2.68346188]).
# [W 2024-09-25 12:09:00,490] Trial 209 failed with parameters: {'n_estimators': 924, 'max_depth': 24, 'min_samples_split': 19, 'min_samples_leaf': 21} because of the following error: The value array([-2.1039199 , -2.86587149, -2.52042439, -2.56237173, -2.93086954]) could not be cast to float.
# [W 2024-09-25 12:09:00,491] Trial 209 failed with value array([-2.1039199 , -2.86587149, -2.52042439, -2.56237173, -2.93086954]).
# [W 2024-09-25 12:09:00,631] Trial 210 failed with parameters: {'n_estimators': 111, 'max_depth': 37, 'min_samples_split': 7, 'min_samples_leaf': 31} because of the following error: The value array([-2.66160543, -4.10755655, -2.84332151, -4.51155468, -4.13359209]) could not be cast to float.
# [W 2024-09-25 12:09:00,631] Trial 210 failed with value array([-2.66160543, -4.10755655, -2.84332151, -4.51155468, -4.13359209]).
# [W 2024-09-25 12:09:00,896] Trial 211 failed with parameters: {'n_estimators': 233, 'max_depth': 26, 'min_samples_split': 4, 'min_samples_leaf': 32} because of the following error: The value array([-2.63046887, -4.23617942, -2.93951985, -4.60468772, -4.44918956]) could not be cast to float.
# [W 2024-09-25 12:09:00,897] Trial 211 failed with value array([-2.63046887, -4.23617942, -2.93951985, -4.60468772, -4.44918956]).
# [W 2024-09-25 12:09:01,494] Trial 212 failed with parameters: {'n_estimators': 552, 'max_depth': 34, 'min_samples_split': 4, 'min_samples_leaf': 25} because of the following error: The value array([-2.37203348, -3.19218883, -2.66287935, -2.80017929, -3.08398773]) could not be cast to float.
# [W 2024-09-25 12:09:01,495] Trial 212 failed with value array([-2.37203348, -3.19218883, -2.66287935, -2.80017929, -3.08398773]).
# [W 2024-09-25 12:09:01,854] Trial 213 failed with parameters: {'n_estimators': 289, 'max_depth': 46, 'min_samples_split': 8, 'min_samples_leaf': 7} because of the following error: The value array([-1.03937329, -0.93323023, -0.93518592, -1.1394156 , -1.42790786]) could not be cast to float.
# [W 2024-09-25 12:09:01,855] Trial 213 failed with value array([-1.03937329, -0.93323023, -0.93518592, -1.1394156 , -1.42790786]).
# [W 2024-09-25 12:09:02,028] Trial 214 failed with parameters: {'n_estimators': 132, 'max_depth': 29, 'min_samples_split': 19, 'min_samples_leaf': 4} because of the following error: The value array([-0.8135514 , -0.6686494 , -0.72769971, -0.8522751 , -1.02271089]) could not be cast to float.
# [W 2024-09-25 12:09:02,029] Trial 214 failed with value array([-0.8135514 , -0.6686494 , -0.72769971, -0.8522751 , -1.02271089]).
# [W 2024-09-25 12:09:02,897] Trial 215 failed with parameters: {'n_estimators': 798, 'max_depth': 28, 'min_samples_split': 18, 'min_samples_leaf': 15} because of the following error: The value array([-2.02659008, -2.31067065, -2.05941607, -2.16763278, -2.738628  ]) could not be cast to float.
# [W 2024-09-25 12:09:02,898] Trial 215 failed with value array([-2.02659008, -2.31067065, -2.05941607, -2.16763278, -2.738628  ]).
# [W 2024-09-25 12:09:03,468] Trial 216 failed with parameters: {'n_estimators': 461, 'max_depth': 32, 'min_samples_split': 6, 'min_samples_leaf': 7} because of the following error: The value array([-1.01082994, -0.90555717, -0.92520696, -1.15313021, -1.38606217]) could not be cast to float.
# [W 2024-09-25 12:09:03,469] Trial 216 failed with value array([-1.01082994, -0.90555717, -0.92520696, -1.15313021, -1.38606217]).
# [W 2024-09-25 12:09:04,602] Trial 217 failed with parameters: {'n_estimators': 876, 'max_depth': 48, 'min_samples_split': 13, 'min_samples_leaf': 10} because of the following error: The value array([-1.46492343, -1.49848503, -1.46935287, -1.68626551, -2.13957732]) could not be cast to float.
# [W 2024-09-25 12:09:04,603] Trial 217 failed with value array([-1.46492343, -1.49848503, -1.46935287, -1.68626551, -2.13957732]).
# [W 2024-09-25 12:09:05,466] Trial 218 failed with parameters: {'n_estimators': 680, 'max_depth': 26, 'min_samples_split': 2, 'min_samples_leaf': 6} because of the following error: The value array([-0.85137806, -0.77071699, -0.76999499, -0.93623755, -1.17052107]) could not be cast to float.
# [W 2024-09-25 12:09:05,467] Trial 218 failed with value array([-0.85137806, -0.77071699, -0.76999499, -0.93623755, -1.17052107]).
# [W 2024-09-25 12:09:06,382] Trial 219 failed with parameters: {'n_estimators': 745, 'max_depth': 37, 'min_samples_split': 2, 'min_samples_leaf': 8} because of the following error: The value array([-1.18025899, -1.08215607, -1.11949854, -1.37172207, -1.62801972]) could not be cast to float.
# [W 2024-09-25 12:09:06,383] Trial 219 failed with value array([-1.18025899, -1.08215607, -1.11949854, -1.37172207, -1.62801972]).
# [W 2024-09-25 12:09:06,784] Trial 220 failed with parameters: {'n_estimators': 308, 'max_depth': 37, 'min_samples_split': 2, 'min_samples_leaf': 5} because of the following error: The value array([-0.63669233, -0.61461332, -0.58907166, -0.72182661, -0.94605916]) could not be cast to float.
# [W 2024-09-25 12:09:06,785] Trial 220 failed with value array([-0.63669233, -0.61461332, -0.58907166, -0.72182661, -0.94605916]).
# [W 2024-09-25 12:09:07,846] Trial 221 failed with parameters: {'n_estimators': 820, 'max_depth': 17, 'min_samples_split': 22, 'min_samples_leaf': 9} because of the following error: The value array([-1.39894901, -1.34114445, -1.36043975, -1.62686944, -2.00320297]) could not be cast to float.
# [W 2024-09-25 12:09:07,847] Trial 221 failed with value array([-1.39894901, -1.34114445, -1.36043975, -1.62686944, -2.00320297]).
# [W 2024-09-25 12:09:08,104] Trial 222 failed with parameters: {'n_estimators': 189, 'max_depth': 19, 'min_samples_split': 24, 'min_samples_leaf': 28} because of the following error: The value array([-2.59877486, -3.55507338, -2.75235872, -3.56092787, -3.44450996]) could not be cast to float.
# [W 2024-09-25 12:09:08,105] Trial 222 failed with value array([-2.59877486, -3.55507338, -2.75235872, -3.56092787, -3.44450996]).
# [W 2024-09-25 12:09:09,393] Trial 223 failed with parameters: {'n_estimators': 848, 'max_depth': 26, 'min_samples_split': 22, 'min_samples_leaf': 8} because of the following error: The value array([-1.30687055, -1.18058296, -1.23748606, -1.48165913, -1.79538886]) could not be cast to float.
# [W 2024-09-25 12:09:09,395] Trial 223 failed with value array([-1.30687055, -1.18058296, -1.23748606, -1.48165913, -1.79538886]).
# [W 2024-09-25 12:09:10,036] Trial 224 failed with parameters: {'n_estimators': 364, 'max_depth': 46, 'min_samples_split': 2, 'min_samples_leaf': 4} because of the following error: The value array([-0.4753385 , -0.4717642 , -0.43697903, -0.51050207, -0.66937706]) could not be cast to float.
# [W 2024-09-25 12:09:10,037] Trial 224 failed with value array([-0.4753385 , -0.4717642 , -0.43697903, -0.51050207, -0.66937706]).
# [W 2024-09-25 12:09:10,545] Trial 225 failed with parameters: {'n_estimators': 287, 'max_depth': 11, 'min_samples_split': 7, 'min_samples_leaf': 20} because of the following error: The value array([-2.09465241, -2.80911413, -2.48148151, -2.50743857, -2.93300209]) could not be cast to float.
# [W 2024-09-25 12:09:10,545] Trial 225 failed with value array([-2.09465241, -2.80911413, -2.48148151, -2.50743857, -2.93300209]).
# [W 2024-09-25 12:09:11,371] Trial 226 failed with parameters: {'n_estimators': 479, 'max_depth': 46, 'min_samples_split': 27, 'min_samples_leaf': 12} because of the following error: The value array([-1.71688234, -2.00959134, -1.82744706, -1.92396429, -2.53450652]) could not be cast to float.
# [W 2024-09-25 12:09:11,372] Trial 226 failed with value array([-1.71688234, -2.00959134, -1.82744706, -1.92396429, -2.53450652]).
# [W 2024-09-25 12:09:11,937] Trial 227 failed with parameters: {'n_estimators': 333, 'max_depth': 25, 'min_samples_split': 20, 'min_samples_leaf': 10} because of the following error: The value array([-1.49110075, -1.47618782, -1.48304903, -1.70284748, -2.17118108]) could not be cast to float.
# [W 2024-09-25 12:09:11,938] Trial 227 failed with value array([-1.49110075, -1.47618782, -1.48304903, -1.70284748, -2.17118108]).
# [W 2024-09-25 12:09:12,976] Trial 228 failed with parameters: {'n_estimators': 662, 'max_depth': 26, 'min_samples_split': 19, 'min_samples_leaf': 15} because of the following error: The value array([-2.01702634, -2.38295964, -2.05937184, -2.17375067, -2.72517228]) could not be cast to float.
# [W 2024-09-25 12:09:12,976] Trial 228 failed with value array([-2.01702634, -2.38295964, -2.05937184, -2.17375067, -2.72517228]).

# %%
study.best_params
