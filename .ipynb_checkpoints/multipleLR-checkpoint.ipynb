# %%
import pandas as pd

# %%
import random

# %%
import numpy as np

# %%
data = []

for _ in range(500):
    team_name = f"Team {chr(random.randint(65, 90))}"
    season = random.randint(2010, 2023)
    wins = random.randint(50, 110)
    losses = 162 - wins
    hits = random.randint(1200, 1600)
    doubles = random.randint(200, 350)
    triples = random.randint(10, 40)
    home_runs = random.randint(100, 250)
    strikeouts = random.randint(1000, 1500)
    
    hits_adjusted = hits + (wins - 80) * 5
    doubles_adjusted = doubles + (wins - 80) * 2
    triples_adjusted = triples + (wins - 80)
    home_runs_adjusted = home_runs + (wins - 80) * 3
    strikeouts_adjusted = strikeouts + (wins - 80) * 10
    
    data.append({
        "team_name": team_name,
        "season": season,
        "wins": wins,
        "losses": losses,
        "hits": hits,
        "doubles": doubles,
        "triples": triples,
        "home_runs": home_runs,
        "strikeouts": strikeouts,
        "hits_adjusted": hits_adjusted,
        "doubles_adjusted": doubles_adjusted,
        "triples_adjusted": triples_adjusted,
        "home_runs_adjusted": home_runs_adjusted,
        "strikeouts_adjusted": strikeouts_adjusted
    })

# %%
df = pd.DataFrame(data)

# %%
df
# Out:
#     team_name  season  wins  losses  hits  doubles  triples  home_runs  \
# 0      Team Q    2016    79      83  1523      230       20        187
# 1      Team C    2014    81      81  1474      349       40        207
# 2      Team V    2019    64      98  1578      281       23        192
# 3      Team H    2014    76      86  1558      230       19        196
# 4      Team H    2023    72      90  1345      319       32        248
# ..        ...     ...   ...     ...   ...      ...      ...        ...
# 495    Team S    2011    81      81  1213      346       23        117
# 496    Team K    2010   110      52  1377      341       21        139
# 497    Team J    2020    53     109  1300      315       36        169
# 498    Team U    2010    91      71  1299      272       18        205
# 499    Team T    2014    71      91  1298      332       14        125
#
#      strikeouts  hits_adjusted  doubles_adjusted  triples_adjusted  \
# 0          1500           1518               228                19
# 1          1315           1479               351                41
# 2          1387           1498               249                 7
# 3          1120           1538               222                15
# 4          1244           1305               303                24
# ..          ...            ...               ...               ...
# 495        1214           1218               348                24
# 496        1455           1527               401                51
# 497        1058           1165               261                 9
# 498        1405           1354               294                29
# 499        1081           1253               314                 5
#
#      home_runs_adjusted  strikeouts_adjusted
# 0                   184                 1490
# 1                   210                 1325
# 2                   144                 1227
# 3                   184                 1080
# 4                   224                 1164
# ..                  ...                  ...
# 495                 120                 1224
# 496                 229                 1755
# 497                  88                  788
# 498                 238                 1515
# 499                  98                  991
#
# [500 rows x 14 columns]

# %%
import seaborn as sns
import matplotlib.pyplot as plt
sns.lmplot(x="hits",y="wins", data=df)
plt.show()

# %%
sns.lmplot(x="strikeouts",y="wins",data=df)
plt.show()

# %%
#Multiple linear Reg

# %%
df2 = df.drop(columns=['team_name','season','losses'], axis=1)

# %%
df2.head()
# Out:
#    wins  hits  doubles  triples  home_runs  strikeouts  hits_adjusted  \
# 0    79  1523      230       20        187        1500           1518
# 1    81  1474      349       40        207        1315           1479
# 2    64  1578      281       23        192        1387           1498
# 3    76  1558      230       19        196        1120           1538
# 4    72  1345      319       32        248        1244           1305
#
#    doubles_adjusted  triples_adjusted  home_runs_adjusted  strikeouts_adjusted
# 0               228                19                 184                 1490
# 1               351                41                 210                 1325
# 2               249                 7                 144                 1227
# 3               222                15                 184                 1080
# 4               303                24                 224                 1164

# %%
df2.columns
# Out:
# Index(['wins', 'hits', 'doubles', 'triples', 'home_runs', 'strikeouts',
#        'hits_adjusted', 'doubles_adjusted', 'triples_adjusted',
#        'home_runs_adjusted', 'strikeouts_adjusted'],
#       dtype='object')

# %%
X= df[['hits', 'doubles', 'triples', 'home_runs', 'strikeouts',
       'hits_adjusted', 'doubles_adjusted', 'triples_adjusted',
       'home_runs_adjusted', 'strikeouts_adjusted']]
y=df['wins']

# %%
from sklearn.model_selection import train_test_split

# %%
X_train, X_test, y_train, y_test = train_test_split(X,y,test_size=0.2, random_state=21)

# %%
from sklearn.linear_model import LinearRegression

# %%
lr = LinearRegression()

# %%
lr.fit(X_train,y_train)
# Out:
# LinearRegression()

# %%
lr.score(X_test,y_test)
# Out:
# 1.0
