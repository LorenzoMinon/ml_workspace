# %%
import matplotlib.pyplot as plt

# Datos para el gráfico de Proyección de Ingresos (8.1)
planes = ['Básico', 'Avanzado', 'Premium']
ingresos = [50 * 100 * 12, 150 * 75 * 12, 300 * 50 * 12]  # Ingresos anuales por cada plan

# Gráfico de barras para Proyección de Ingresos
plt.figure(figsize=(8, 5))
plt.bar(planes, ingresos, color=['#4CAF50', '#2196F3', '#FF5722'])
plt.title('Proyección de Ingresos por Plan de Suscripción (8.1)', fontsize=14)
plt.ylabel('Ingresos Anuales en USD', fontsize=12)
plt.xlabel('Planes de Suscripción', fontsize=12)
plt.tight_layout()
plt.show()

# %%
# Datos para el gráfico de Distribución de Costos (8.2)
costos = ['Producción', 'Comercialización', 'Administración']
monto_costos = [30000, 7500, 10000]  # Monto en USD para cada categoría

# Gráfico circular para la distribución de costos
plt.figure(figsize=(7, 7))
plt.pie(monto_costos, labels=costos, autopct='%1.1f%%', startangle=140, colors=['#FF9999', '#66B2FF', '#99FF99'])
plt.title('Distribución de Costos (8.2)', fontsize=14)
plt.axis('equal')  # Para que sea un círculo perfecto
plt.show()

# %%
# Datos para el gráfico de Inversión (8.3)
categorias = ['Hardware', 'Software', 'Redes', 'Muebles', 'Gastos de Instalación', 'Capacitación', 'Legal']
inversion = [10000, 2000, 2000, 7000, 5000, 2000, 2000]

# Gráfico de barras para la inversión en cada categoría
plt.figure(figsize=(10, 6))
plt.bar(categorias, inversion, color='#3399FF')
plt.title('Inversión por Categorías (8.3)', fontsize=14)
plt.ylabel('Inversión en USD', fontsize=12)
plt.xticks(rotation=45, ha='right')
plt.tight_layout()
plt.show()

# %%
# Datos de depreciación y amortización
años = [1, 2, 3, 4, 5]
depreciacion_hardware = [2000, 2000, 2000, 2000, 2000]
depreciacion_software = [667, 667, 667, 0, 0]

# Gráfico de líneas para la depreciación
plt.figure(figsize=(8, 5))
plt.plot(años, depreciacion_hardware, label='Hardware', marker='o')
plt.plot(años, depreciacion_software, label='Software', marker='o')
plt.title('Depreciaciones y Amortizaciones (8.4)', fontsize=14)
plt.xlabel('Años', fontsize=12)
plt.ylabel('Monto en USD', fontsize=12)
plt.legend()
plt.tight_layout()
plt.show()

# %%
# Datos de impuestos
impuestos = ['Impuesto a las Ganancias', 'Ingresos Brutos']
monto_impuestos = [25750, 6240]

# Gráfico de barras para impuestos
plt.figure(figsize=(8, 5))
plt.bar(impuestos, monto_impuestos, color=['#FF6666', '#6699FF'])
plt.title('Impacto de los Impuestos (8.5)', fontsize=14)
plt.ylabel('Monto en USD', fontsize=12)
plt.tight_layout()
plt.show()

# %%
# Datos de flujo de caja
meses = ['Enero', 'Febrero', 'Marzo', 'Abril', 'Mayo', 'Junio', 'Julio', 'Agosto', 'Septiembre', 'Octubre', 'Noviembre', 'Diciembre']
ingresos = [10000, 12000, 11000, 13000, 12500, 13500, 14000, 14500, 15000, 15500, 16000, 17000]
egresos = [5000, 6000, 5500, 7000, 6800, 7200, 7500, 7800, 8000, 8200, 8500, 9000]

# Gráfico de líneas para el flujo de caja
plt.figure(figsize=(10, 6))
plt.plot(meses, ingresos, label='Ingresos', marker='o', color='g')
plt.plot(meses, egresos, label='Egresos', marker='o', color='r')
plt.title('Proyección de Flujo de Caja (8.8)', fontsize=14)
plt.ylabel('Monto en USD', fontsize=12)
plt.xticks(rotation=45)
plt.legend()
plt.tight_layout()
plt.show()

# %%
# Datos para el gráfico del Punto de Equilibrio
suscripciones = ['Suscripciones Necesarias']
punto_equilibrio = [392]

# Gráfico de barras para el punto de equilibrio
plt.figure(figsize=(6, 5))
plt.bar(suscripciones, punto_equilibrio, color='#FF9933')
plt.title('Punto de Equilibrio (8.9)', fontsize=14)
plt.ylabel('Número de Suscripciones', fontsize=12)
plt.tight_layout()
plt.show()

# %%
# Datos de escenarios de riesgo
escenarios = ['Base', 'Optimista', 'Pesimista']
flujos_caja = [53980, 142950, 40525]

# Gráfico de barras comparativas para los escenarios de riesgo
plt.figure(figsize=(8, 5))
plt.bar(escenarios, flujos_caja, color=['#4CAF50', '#2196F3', '#FF5722'])
plt.title('Escenarios de Riesgo (8.10)', fontsize=14)
plt.ylabel('Flujo de Caja Neto en USD', fontsize=12)
plt.tight_layout()
plt.show()
